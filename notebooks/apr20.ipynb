# %%
import tensorflow as tf
import numpy
import os
import json, pickle
import pandas
from functools import partial, reduce
import importlib

import sys
sys.path.append('../libs')

import flacdb
import prepare_data
import initialize
import data_pipeline
import loss_metrics
import conv_model
import plot_batch

# %%
! nvidia-smi
# Out:
# Tue Apr 21 20:33:55 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.78       Driver Version: 410.78       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX TIT...  On   | 00000000:05:00.0 Off |                  N/A |
# | 22%   28C    P8    16W / 250W |  11837MiB / 12212MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      4058      C   ...uprel/blood-pressure/env3p7/bin/python3 11826MiB |
# +-----------------------------------------------------------------------------+

# %%
icd_data = json.load(open('/scr-ssd/icd/icd9.json'))
icd_data[0]
# Out:
# [{'code': '001-139',
#   'depth': 1,
#   'href': '/index.php?action=child&recordid=1',
#   'descr': 'INFECTIOUS AND PARASITIC DISEASES '},
#  {'code': '001-009',
#   'depth': 2,
#   'href': '/index.php?action=child&recordid=2',
#   'descr': 'INTESTINAL INFECTIOUS DISEASES '},
#  {'code': '001',
#   'depth': 3,
#   'href': '/index.php?action=child&recordid=3',
#   'descr': 'Cholera'},
#  {'code': '001.9', 'depth': 4, 'href': None, 'descr': 'Cholera, unspecified'}]

# %%
def _to_string(i, with_dot):
    a = str(i[0]).zfill(3)
    b = ''.join(str(j) for j in i[1:])
    dot = '.' if with_dot and len(i) > 1 else ''
    return a + dot + b

def code_tuple_to_string(i):
    return _to_string(i, with_dot=False)

def code_string_to_tuple(i):
    return (int(i[:3]), *[int(j) for j in i[3:]])

def group_string_to_tuple(i):
    if '-' in i:
        return tuple((int(j),) for j in i.split('-'))
    elif '.' in i:
        a, b = i.split('.')
        return ((int(a), *[int(j) for j in b]),)
    else:
        return ((int(i),),)

def group_tuple_to_string(i):
    return '-'.join(_to_string(j, with_dot=True) for j in i)

# %%
root = '/scr1/mimic/'
clinic_file = lambda i: root + 'clinic/{}.csv'.format(i.upper())
diagnosis_info = pandas.read_csv(clinic_file('d_icd_diagnoses'))
diagnosis_info = diagnosis_info.drop(columns='ROW_ID').set_index('ICD9_CODE')
diagnosis_info.rename(columns={'LONG_TITLE': 'Condition'}, inplace=True)
diagnosis = pandas.read_csv(clinic_file('diagnoses_icd')).drop(columns='ROW_ID')
new_names = {i.upper(): i for i in ['subject_id', 'hadm_id']}
new_names['ICD9_CODE'] = 'code'
diagnosis = diagnosis[new_names].rename(columns=new_names)
diagnosis[:5]
# Out:
#    subject_id  hadm_id   code
# 0         109   172335  40301
# 1         109   172335    486
# 2         109   172335  58281
# 3         109   172335   5855
# 4         109   172335   4254

# %%
code_counts = diagnosis['code'].value_counts()
code_counts = pandas.concat([
    diagnosis_info.reindex(code_counts.index)[['Condition']], 
    pandas.Series(code_counts, name='Count')
], axis=1)
code_counts[:10]
# Out:
#                                                Condition  Count
# 4019                  Unspecified essential hypertension  20703
# 4280               Congestive heart failure, unspecified  13111
# 42731                                Atrial fibrillation  12891
# 41401  Coronary atherosclerosis of native coronary ar...  12429
# 5849                   Acute kidney failure, unspecified   9119
# 25000  Diabetes mellitus without mention of complicat...   9058
# 2724                Other and unspecified hyperlipidemia   8690
# 51881                          Acute respiratory failure   7497
# 5990         Urinary tract infection, site not specified   6555
# 53081                                  Esophageal reflux   6326

# %%
code_strings = {i for i in code_counts.index if i[0] in '0123456789'}

code_tuples = {code_string_to_tuple(i) for i in code_strings}

group_strings = {
    j['code']: j['descr'].title()
    for i in icd_data for j in i 
    if j['code'] is not None and j['code'][0] in '0123456789'   
}

group_tuples = {group_string_to_tuple(i) for i in group_strings}

assert(len(code_tuples) == len(code_strings))

assert(all(
    code_tuple_to_string(code_string_to_tuple(i)) == i 
    for i in code_strings
))

assert(len(group_tuples) == len(group_strings))

assert(all(
    group_tuple_to_string(group_string_to_tuple(i)) == i 
    for i in group_strings
))

# %%
groups = {group_string_to_tuple(i): group_strings[i] for i in group_strings}
pandas.DataFrame.from_dict({'name': {str(k): groups[k] for k in groups}})
# Out:
#                                                              name
# ((1, 0),)                                  Due To Vibrio Cholerae
# ((1, 1),)                           Due To Vibrio Cholerae El Tor
# ((1, 9),)                                    Cholera, Unspecified
# ((1,), (139,))                 Infectious And Parasitic Diseases
# ((1,), (9,))                      Intestinal Infectious Diseases
# ...                                                           ...
# ((999, 8, 2),)              Extravasation Of Other Vesicant Agent
# ((999, 8, 8),)                            Other Infusion Reaction
# ((999, 8, 9),)                         Other Transfusion Reaction
# ((999, 9),)     Other And Unspecified Complications Of Medical...
# ((999,),)       Complications Of Medical Care, Not Elsewhere C...
#
# [9719 rows x 1 columns]

# %%
def is_contained(code, group):
    if len(group) == 1:
        node = group[0]
        if node[0] != code[0] or len(node) > len(code):
            return False
        return all(node[i] == code[i] for i in range(len(node)))
    else:
        return group[0][0] <= code[0] <= group[1][0]

# %%
# %%time

code_groups = {
    c: [g for g in groups if is_contained(c, g)] 
    for c in code_tuples
}
# Out:
# CPU times: user 16.6 s, sys: 24 ms, total: 16.6 s
# Wall time: 16.6 s

# %%
diag_ = diagnosis.drop_duplicates()
diag_ = diag_.set_index(['subject_id', 'hadm_id', 'code'])
diag_ = diag_.sort_index()

# %%
# %%time
group_diagnosis = {}
for i in diag_.index.get_level_values('subject_id').unique():
    for j in diag_.loc[i].index.get_level_values('hadm_id').unique():
        group_diagnosis[i, j] = set()
        for k in diag_.loc[(i, j)].index:
            if type(k) is str and k[0] in '0123456789':
                code = code_string_to_tuple(k)
                group_diagnosis[i, j].update(code_groups[code])
# Out:
# CPU times: user 2min 28s, sys: 380 ms, total: 2min 28s
# Wall time: 2min 28s

# %%
group_counts = {group: 0 for group in groups}
for i in group_diagnosis:
    for group in group_diagnosis[i]:
        group_counts[group] += 1

df = pandas.DataFrame.from_dict({
    'name': {group_tuple_to_string(k): groups[k] for k in groups},
    'count': {group_tuple_to_string(k): group_counts[k] for k in group_counts}
})
df.sort_values(['count'], ascending=False, inplace=True)
df[:50]
# Out:
#                                                       name  count
# 390-459                Diseases Of The Circulatory System   42650
# 240-279  Endocrine, Nutritional And Metabolic Diseases,...  35606
# 270-279            Other Metabolic And Immunity Disorders   28210
# 401-405                              Hypertensive Disease   27912
# 420-429                      Other Forms Of Heart Disease   26025
# 460-519                Diseases Of The Respiratory System   25260
# 800-999                              Injury And Poisoning   22686
# 580-629              Diseases Of The Genitourinary System   21779
# 401                                 Essential Hypertension  21305
# 520-579                  Diseases Of The Digestive System   21010
# 401.9                                          Unspecified  20696
# 780-799       Symptoms, Signs, And Ill-Defined Conditions   20182
# 280-289    Diseases Of The Blood And Blood-Forming Organs   19366
# 427                                   Cardiac Dysrhythmias  17226
# 780-789                                          Symptoms   16901
# 410-414                            Ischemic Heart Disease   16854
# 510-519              Other Diseases Of Respiratory System   16273
# 290-319                                  Mental Disorders   16245
# 320-389   Diseases Of The Nervous System And Sense Organs   15828
# 249-259                Diseases Of Other Endocrine Glands   15786
# 580-589      Nephritis, Nephrotic Syndrome, And Nephrosis   15401
# 276      Disorders Of Fluid, Electrolyte, And Acid-Base...  15101
# 272                         Disorders Of Lipoid Metabolism  14558
# 001-139                 Infectious And Parasitic Diseases   14535
# 414          Other Forms Of Chronic Ischemic Heart Disease  14410
# 250                                      Diabetes Mellitus  14222
# 414.0                             Coronary Atherosclerosis  13999
# 428                                          Heart Failure  13608
# 518                                 Other Diseases Of Lung  13346
# 427.3                      Atrial Fibrillation And Flutter  13274
# 428.0                Congestive Heart Failure, Unspecified  13111
# 427.31                                 Atrial Fibrillation  12886
# 996-999  Complications Of Surgical And Medical Care, No...  12734
# 285                          Other And Unspecified Anemias  12606
# 414.01                           Of Native Coronary Artery  12428
# 300-316  Neurotic Disorders, Personality Disorders, And...  12067
# 584                                    Acute Renal Failure  11422
# 490-496  Chronic Obstructive Pulmonary Disease And Alli...  10133
# 710-739  Diseases Of The Musculoskeletal System And Con...  10053
# 030-041                          Other Bacterial Diseases   10032
# 530-538      Diseases Of Esophagus, Stomach, And Duodenum    9880
# 250.0    Diabetes Mellitus Without Mention Of Complication   9854
# 518.8                               Other Diseases Of Lung   9794
# 584.9                     Acute Renal Failure, Unspecified   9118
# 140-239                                         Neoplasms    8912
# 590-599                  Other Diseases Of Urinary System    8857
# 451-459  Diseases Of Veins And Lymphatics, And Other Di...   8792
# 570-579                Other Diseases Of Digestive System    8791
# 272.4                 Other And Unspecified Hyperlipidemia   8689
# 518.81                           Acute Respiratory Failure   7497

# %%
df[df.apply(lambda i: 'malignant' in i['name'].lower(), axis=1)][:50]
# Out:
#                                                       name  count
# 190-199  Malignant Neoplasm Of Other And Unspecified Si...   3401
# 198      Secondary Malignant Neoplasm Of Other Specifie...   1810
# 197      Secondary Malignant Neoplasm Of Respiratory An...   1748
# 150-159  Malignant Neoplasm Of Digestive Organs And Per...   1570
# 200-208  Malignant Neoplasm Of Lymphatic And Hematopoie...   1481
# 160-165  Malignant Neoplasm Of Respiratory And Intratho...   1247
# 162      Malignant Neoplasm Of Trachea, Bronchus, And Lung   1171
# 179-189        Malignant Neoplasm Of Genitourinary Organs     788
# 196      Secondary And Unspecified Malignant Neoplasm O...    709
# 202      Other Malignant Neoplasms Of Lymphoid And Hist...    498
# 155      Malignant Neoplasm Of Liver And Intrahepatic B...    454
# 170-176  Malignant Neoplasm Of Bone, Connective Tissue,...    318
# 185                         Malignant Neoplasm Of Prostate    302
# 191                            Malignant Neoplasm Of Brain    280
# 157                         Malignant Neoplasm Of Pancreas    276
# 189      Malignant Neoplasm Of Kidney And Other And Uns...    236
# 403.0                                            Malignant    227
# 153                            Malignant Neoplasm Of Colon    218
# 150                        Malignant Neoplasm Of Esophagus    214
# 151                          Malignant Neoplasm Of Stomach    177
# 199       Malignant Neoplasm Without Specification Of Site    174
# 401.0                                            Malignant    172
# 174                    Malignant Neoplasm Of Female Breast    142
# 511.81                          Malignant Pleural Effusion    132
# 200      Lymphosarcoma And Reticulosarcoma And Other Sp...    131
# 188                          Malignant Neoplasm Of Bladder    123
# 156      Malignant Neoplasm Of Gallbladder And Extrahep...    103
# 140-149  Malignant Neoplasm Of Lip, Oral Cavity, And Ph...     98
# 183      Malignant Neoplasm Of Ovary And Other Uterine ...     82
# 154      Malignant Neoplasm Of Rectum, Rectosigmoid Jun...     79
# 789.51                                   Malignant Ascites     55
# 172                             Malignant Melanoma Of Skin     54
# 173                       Other Malignant Neoplasm Of Skin     52
# 193                    Malignant Neoplasm Of Thyroid Gland     49
# 171      Malignant Neoplasm Of Connective And Other Sof...     43
# 161                           Malignant Neoplasm Of Larynx     38
# 158      Malignant Neoplasm Of Retroperitoneum And Peri...     31
# 152      Malignant Neoplasm Of Small Intestine, Includi...     30
# 182                   Malignant Neoplasm Of Body Of Uterus     27
# 141                           Malignant Neoplasm Of Tongue     25
# 164      Malignant Neoplasm Of Thymus, Heart, And Media...     24
# 195      Malignant Neoplasm Of Other And Ill-Defined Sites     17
# 180                     Malignant Neoplasm Of Cervix Uteri     16
# 147                      Malignant Neoplasm Of Nasopharynx     15
# 209.2    Malignant Carcinoid Tumors Of Other And Unspec...     14
# 170      Malignant Neoplasm Of Bone And Articular Carti...     14
# 404.0                                            Malignant     13
# 192      Malignant Neoplasm Of Other And Unspecified Pa...     12
# 146                       Malignant Neoplasm Of Oropharynx     12
# 163                           Malignant Neoplasm Of Pleura     11

# %%
df.index.map(lambda i: '03' in i)
# Out:
# Index([False, False, False, False, False, False, False, False, False, False,
#        ...
#        False, False, False, False, False, False, False, False, False, False],
#       dtype='object', length=9719)

# %%
df[df.index.map(lambda i: i[0] == '7')][:50]
# Out:
#                                                       name  count
# 780-799       Symptoms, Signs, And Ill-Defined Conditions   20182
# 780-789                                          Symptoms   16901
# 710-739  Diseases Of The Musculoskeletal System And Con...  10053
# 760-779  Certain Conditions Originating In The Perinata...   5488
# 764-779  Other Conditions Originating In The Perinatal ...   5458
# 780                                       General Symptoms   5449
# 785               Symptoms Involving Cardiovascular System   5351
# 790-796                     Nonspecific Abnormal Findings    4586
# 785.5                      Shock Without Mention Of Trauma   4283
# 730-739  Osteopathies, Chondropathies, And Acquired Mus...   3794
# 790           Nonspecific Findings On Examination Of Blood   3730
# 710-719               Arthropathies And Related Disorders    3678
# 700-709    Other Diseases Of Skin And Subcutaneous Tissue    3527
# 765      Disorders Relating To Short Gestation And Low ...   3430
# 740-759                              Congenital Anomalies    3205
# 707                                  Chronic Ulcer Of Skin   3186
# 765.1                                Other Preterm Infants   3052
# 774                               Other Perinatal Jaundice   2928
# 765.2                                   Weeks Of Gestation   2923
# 733                  Other Disorders Of Bone And Cartilage   2799
# 770      Other Respiratory Conditions Of Fetus And Newborn   2775
# 785.52                                        Septic Shock   2586
# 720-724                                      Dorsopathies    2438
# 787                    Symptoms Involving Digestive System   2408
# 774.2    Neonatal Jaundice Associated With Preterm Deli...   2264
# 725-729                    Rheumatism, Excluding The Back    2207
# 707.0                                       Pressure Ulcer   2107
# 789            Other Symptoms Involving Abdomen And Pelvis   2017
# 733.0                                         Osteoporosis   1986
# 788                      Symptoms Involving Urinary System   1975
# 770.8               Other Respiratory Problems After Birth   1947
# 733.00                           Osteoporosis, Unspecified   1946
# 780.3                                          Convulsions   1943
# 780.39                                   Other Convulsions   1934
# 797-799  Ill-Defined And Unknown Causes Of Morbidity An...   1667
# 799      Other Ill-Defined And Unknown Causes Of Morbid...   1666
# 779      Other And Ill-Defined Conditions Originating I...   1662
# 789.5                                              Ascites   1566
# 790.7                                           Bacteremia   1478
# 715                    Osteoarthrosis And Allied Disorders   1453
# 786      Symptoms Involving Respiratory System And Othe...   1433
# 784                       Symptoms Involving Head And Neck   1396
# 724                Other And Unspecified Disorders Of Back   1354
# 799.0                               Asphyxia And Hypoxemia   1329
# 769                          Respiratory Distress Syndrome   1314
# 799.02                                           Hypoxemia   1298
# 707.03                                          Lower Back   1289
# 788.2                                   Retention Of Urine   1247
# 785.51                                   Cardiogenic Shock   1154
# 715.9    Osteoarthrosis, Unspecified Whether Generalize...   1139

# %%
df[df.index.map(lambda i: i[:2] == '45')][:50]
# Out:
#                                                       name  count
# 451-459  Diseases Of Veins And Lymphatics, And Other Di...   8792
# 458                                            Hypotension   5045
# 458.2                               Iatrogenic Hypotension   2453
# 458.29                        Other Iatrogenic Hypotension   2121
# 458.9                             Hypotension, Unspecified   2051
# 453                   Other Venous Embolism And Thrombosis   1556
# 456                          Varicose Veins Of Other Sites   1000
# 453.8                             Of Other Specified Veins    886
# 459                  Other Disorders Of Circulatory System    828
# 456.2    Esophageal Varices In Diseases Classified Else...    770
# 453.4    Venous Embolism And Thrombosis Of Deep Vessels...    536
# 459.8      Other Specified Disorders Of Circulatory System    530
# 455                                            Hemorrhoids    504
# 459.81      Venous (Peripheral) Insufficiency, Unspecified    503
# 456.21                         Without Mention Of Bleeding    418
# 451                         Phlebitis And Thrombophlebitis    386
# 451.8                                       Of Other Sites    359
# 456.20                                       With Bleeding    352
# 453.41   Venous Embolism And Thrombosis Of Deep Vessels...    331
# 458.0                              Orthostatic Hypotension    286
# 458.8                          Other Specified Hypotension    279
# 452                                 Portal Vein Thrombosis    257
# 455.0    Internal Hemorrhoids Without Mention Of Compli...    212
# 451.82           Of Superficial Veins Of Upper Extremities    202
# 456.8                               Varices Of Other Sites    188
# 459.2                                  Compression Of Vein    161
# 453.42   Venous Embolism And Thrombosis Of Deep Vessels...    136
# 457          Noninfectious Disorders Of Lymphatic Channels    128
# 456.1       Esophageal Varices Without Mention Of Bleeding    122
# 458.21                         Hypotension Of Hemodialysis    120
# 459.0                              Hemorrhage, Unspecified    115
# 451.84                   Of Upper Extremities, Unspecified    112
# 455.2         Internal Hemorrhoids With Other Complication    102
# 453.40   Venous Embolism And Thrombosis Of Unspecified ...     95
# 453.2                                         Of Vena Cava     79
# 455.6    Unspecified Hemorrhoids Without Mention Of Com...     69
# 455.3    External Hemorrhoids Without Mention Of Compli...     68
# 457.1                                     Other Lymphedema     66
# 455.8      Unspecified Hemorrhoids With Other Complication     58
# 454                    Varicose Veins Of Lower Extremities     55
# 457.8    Other Noninfectious Disorders Of Lymphatic Cha...     47
# 454.9                          Asymptomatic Varicose Veins     44
# 455.5         External Hemorrhoids With Other Complication     43
# 451.89                                               Other     38
# 456.0                     Esophageal Varices With Bleeding     33
# 459.89                                               Other     28
# 459.9              Unspecified Circulatory System Disorder     26
# 453.9                                  Of Unspecified Site     19
# 451.1                 Of Deep Vessels Of Lower Extremities     14
# 457.0                   Postmastectomy Lymphedema Syndrome     14

# %%
df[300:350]
# Out:
#                                                       name  count
# 415                          Acute Pulmonary Heart Disease   1116
# 413                                        Angina Pectoris   1115
# 300.4                                   Dysthymic Disorder   1109
# 415.1                    Pulmonary Embolism And Infarction   1109
# 519                   Other Diseases Of Respiratory System   1107
# 576                       Other Disorders Of Biliary Tract   1104
# 574                                         Cholelithiasis   1100
# 413.9                Other And Unspecified Angina Pectoris   1100
# 428.22                                             Chronic   1097
# 569                           Other Disorders Of Intestine   1096
# 997.3                            Respiratory Complications   1091
# 560.1                                      Paralytic Ileus   1072
# 807       Fracture Of Rib(S), Sternum, Larynx, And Trachea   1072
# 535                               Gastritis And Duodenitis   1068
# 779.3                          Feeding Problems In Newborn   1068
# 570                   Acute And Subacute Necrosis Of Liver   1067
# 567             Peritonitis And Retroperitoneal Infections   1064
# 790.9    Other Nonspecific Findings On Examination Of B...   1062
# 787.9            Other Symptoms Involving Digestive System   1060
# 493.2                           Chronic Obstructive Asthma   1059
# 038.4      Septicemia Due To Other Gram-Negative Organisms   1050
# 787.91                                            Diarrhea   1049
# 770.81                            Primary Apnea Of Newborn   1043
# 729                        Other Disorders Of Soft Tissues   1040
# 284      Aplastic Anemia And Other Bone Marrow Failure ...   1040
# 788.20                     Retention Of Urine, Unspecified   1020
# 805      Fracture Of Vertebral Column Without Mention O...   1009
# 593                   Other Disorders Of Kidney And Ureter   1009
# 572.3                                  Portal Hypertension   1007
# 345.9                                Epilepsy, Unspecified   1006
# 456                          Varicose Veins Of Other Sites   1000
# 790.92                        Abnormal Coagulation Profile    994
# 482.4                      Pneumonia Due To Staphylococcus    993
# 807.0                                       Rib(S), Closed    993
# 276.3                                            Alkalosis    984
# 250.5              Diabetes With Ophthalmic Manifestations    982
# 512                                           Pneumothorax    980
# 789.59                                       Other Ascites    978
# 348.5                                       Cerebral Edema    978
# 820-829                            Fracture Of Lower Limb     966
# 779.8    Other Specified Conditions Originating In The ...    963
# 577.0                                   Acute Pancreatitis    961
# 433.1                                       Carotid Artery    959
# 873                               Other Open Wound Of Head    954
# 996.62           Due To Vascular Device, Implant And Graft    950
# 707.2                                Pressure Ulcer Stages    945
# 276.6                                       Fluid Overload    945
# 599.7                                            Hematuria    937
# 998.2    Accidental Puncture Or Laceration During A Pro...    929
# 810-819                            Fracture Of Upper Limb     913

# %%
df[350:400]
# Out:
#                                                       name  count
# 787.2                                            Dysphagia    913
# 362.0                                 Diabetic Retinopathy    908
# 780.5                                   Sleep Disturbances    907
# 396                   Diseases Of Mitral And Aortic Valves    906
# 041.0                                        Streptococcus    899
# 453.8                             Of Other Specified Veins    886
# 765.27                            33-34 Weeks Of Gestation    881
# 745      Bulbus Cordis Anomalies And Anomalies Of Cardi...    876
# 960-979  Poisoning By Drugs, Medicinal And Biological S...    876
# 362.01                     Background Diabetic Retinopathy    875
# 997.4                       Digestive System Complications    875
# 765.28                            35-36 Weeks Of Gestation    874
# 250.1                           Diabetes With Ketoacidosis    874
# 852.2    Subdural Hemorrhage Following Injury Without M...    866
# 414.8    Other Specified Forms Of Chronic Ischemic Hear...    865
# 996.8                  Complications Of Transplanted Organ    861
# 415.19                                               Other    859
# 999      Complications Of Medical Care, Not Elsewhere C...    856
# 562.10   Diverticulosis Of Colon (Without Mention Of He...    849
# 198.5                                 Bone And Bone Marrow    843
# 567.2                        Other Suppurative Peritonitis    838
# 564.00                           Constipation, Unspecified    830
# 459                  Other Disorders Of Circulatory System    828
# 423                          Other Diseases Of Pericardium    826
# 038.1                            Staphylococcal Septicemia    825
# 235-238                   Neoplasms Of Uncertain Behavior     819
# 470-478     Other Diseases Of The Upper Respiratory Tract     819
# 291.81                                  Alcohol Withdrawal    812
# 291.8     Other Specified Alcohol-Induced Mental Disorders    812
# 428.30                                         Unspecified    800
# 728              Disorders Of Muscle, Ligament, And Fascia    798
# 782      Symptoms Involving Skin And Other Integumentar...    794
# 197.7                        Liver, Specified As Secondary    794
# 437          Other And Ill-Defined Cerebrovascular Disease    790
# 342                             Hemiplegia And Hemiparesis    790
# 482.41   Methicillin Susceptible Pneumonia Due To Staph...    789
# 519.1    Other Diseases Of Trachea And Bronchus, Not El...    788
# 179-189        Malignant Neoplasm Of Genitourinary Organs     788
# 512.1                              Iatrogenic Pneumothorax    786
# 397               Diseases Of Other Endocardial Structures    780
# 397.0                          Diseases Of Tricuspid Valve    779
# 456.2    Esophageal Varices In Diseases Classified Else...    770
# 198.3                                Brain And Spinal Cord    767
# 434.9               Cerebral Artery Occlusion, Unspecified    761
# 518.82   Other Pulmonary Insufficiency, Not Elsewhere C...    761
# 775      Endocrine And Metabolic Disturbances Specific ...    755
# 770.6                      Transitory Tachypnea Of Newborn    754
# 197.0                                                 Lung    754
# 728.8      Other Disorders Of Muscle, Ligament, And Fascia    752
# 780.0                          Alteration Of Consciousness    749

# %%
df[400:450]
# Out:
#                                                      name  count
# 365                                              Glaucoma    742
# 070.7                       Unspecified Viral Hepatitis C    740
# 557                   Vascular Insufficiency Of Intestine    736
# 585.3        Chronic Kidney Disease, Stage Iii (Moderate)    735
# 349     Other And Unspecified Disorders Of The Nervous...    733
# 682.6                                    Leg, Except Foot    732
# 537               Other Disorders Of Stomach And Duodenum    730
# 348.4                                Compression Of Brain    711
# 365.9                                Unspecified Glaucoma    711
# 250.8        Diabetes With Other Specified Manifestations    711
# 583     Nephritis And Nephropathy, Not Specified As Ac...    710
# 338.2                                        Chronic Pain    710
# 196     Secondary And Unspecified Malignant Neoplasm O...    709
# 041.11      Methicillin Susceptible Staphylococcus Aureus    703
# 295                               Schizophrenic Disorders    700
# 238     Neoplasm Of Uncertain Behavior Of Other And Un...    696
# 275.4                     Disorders Of Calcium Metabolism    695
# 518.89   Other Diseases Of Lung, Not Elsewhere Classified    694
# 714     Rheumatoid Arthritis And Other Inflammatory Po...    693
# 338.29                                 Other Chronic Pain    692
# 578.1                                      Blood In Stool    690
# 428.4       Combined Systolic And Diastolic Heart Failure    689
# 304                                       Drug Dependence    689
# 568                         Other Disorders Of Peritoneum    685
# 536                      Disorders Of Function Of Stomach    685
# 492                                             Emphysema    684
# 518.84              Acute And Chronic Respiratory Failure    684
# 253     Disorders Of The Pituitary Gland And Its Hypot...    681
# 593.9           Unspecified Disorder Of Kidney And Ureter    679
# 747      Other Congenital Anomalies Of Circulatory System    678
# 348.30                        Encephalopathy, Unspecified    674
# 070.70  Unspecified Viral Hepatitis C Without Hepatic ...    674
# 860                 Traumatic Pneumothorax And Hemothorax    673
# 572.2                                        Hepatic Coma    666
# 349.8         Other Specified Disorders Of Nervous System    664
# 553.3                                Diaphragmatic Hernia    663
# 576.1                                         Cholangitis    662
# 441.4       Abdominal Aneurysm Without Mention Of Rupture    660
# 296.8             Other And Unspecified Bipolar Disorders    660
# 774.6             Unspecified Fetal And Neonatal Jaundice    659
# 430                               Subarachnoid Hemorrhage    658
# 434.1                                   Cerebral Embolism    654
# 714.0                                Rheumatoid Arthritis    649
# 294.1         Dementia In Conditions Classified Elsewhere    648
# 801                             Fracture Of Base Of Skull    647
# 112.0                                            Of Mouth    646
# 349.82                               Toxic Encephalopathy    642
# 492.8                                     Other Emphysema    641
# 041.8                Other Specified Bacterial Infections    636
# 802                                Fracture Of Face Bones    634

# %%
df[450:500]
# Out:
#                                                       name  count
# 569.8               Other Specified Disorders Of Intestine    632
# 342.9                              Hemiplegia, Unspecified    632
# 930-939  Effects Of Foreign Body Entering Through Orifice     628
# 730      Osteomyelitis, Periostitis, And Other Infectio...    620
# 583.8    With Other Specified Pathological Lesion In Ki...    617
# 041.04                              Group D [Enterococcus]    614
# 294.10   Dementia In Conditions Classified Elsewhere Wi...    613
# 255                            Disorders Of Adrenal Glands    610
# 438.8        Other Late Effects Of Cerebrovascular Disease    608
# 785.0                             Tachycardia, Unspecified    607
# 779.81                                Neonatal Bradycardia    606
# 296.80                       Bipolar Disorder, Unspecified    603
# 781      Symptoms Involving Nervous And Musculoskeletal...    603
# 410.4                               Of Other Inferior Wall    602
# 583.81   Nephritis And Nephropathy, Not Specified As Ac...    594
# 520-529  Diseases Of Oral Cavity, Salivary Glands, And ...    591
# 535.5           Unspecified Gastritis And Gastroduodenitis    588
# 289       Other Diseases Of Blood And Blood-Forming Organs    587
# 292                          Drug-Induced Mental Disorders    586
# 770.89              Other Respiratory Problems After Birth    583
# 780.57                             Unspecified Sleep Apnea    581
# 346                                               Migraine    579
# 780.09                                               Other    577
# 331.4                            Obstructive Hydrocephalus    576
# 996.74          Due To Vascular Device, Implant, And Graft    576
# 410.1                               Of Other Anterior Wall    574
# 746                    Other Congenital Anomalies Of Heart    573
# 333      Other Extrapyramidal Disease And Abnormal Move...    571
# 427.4                 Ventricular Fibrillation And Flutter    571
# 331.0                                  Alzheimer'S Disease    569
# 427.41                            Ventricular Fibrillation    568
# 238.7            Other Lymphatic And Hematopoietic Tissues    565
# 997.31                     Ventilator Associated Pneumonia    564
# 537.8    Other Specified Disorders Of Stomach And Duodenum    556
# 997.0                         Nervous System Complications    554
# 531                                          Gastric Ulcer    549
# 693          Dermatitis Due To Substances Taken Internally    547
# 515                    Postinflammatory Pulmonary Fibrosis    544
# 693.0                           Due To Drugs And Medicines    543
# 429      Ill-Defined Descriptions And Complications Of ...    543
# 305.6                                        Cocaine Abuse    542
# 042             Human Immunodeficiency Virus [Hiv] Disease    538
# 276.4                     Mixed Acid-Base Balance Disorder    536
# 453.4    Venous Embolism And Thrombosis Of Deep Vessels...    536
# 785.59                                               Other    535
# 519.19              Other Diseases Of Trachea And Bronchus    534
# 776                     Hematological Disorders Of Newborn    532
# 346.9                                Migraine, Unspecified    530
# 478              Other Diseases Of Upper Respiratory Tract    530
# 459.8      Other Specified Disorders Of Circulatory System    530

# %%
df[500:550]
# Out:
#                                                       name  count
# 426.0                     Atrioventricular Block, Complete    530
# 380-389           Diseases Of The Ear And Mastoid Process     523
# 344                              Other Paralytic Syndromes    521
# 996.81                                              Kidney    515
# 038.11   Methicillin Susceptible Staphylococcus Aureus ...    515
# 532                                         Duodenal Ulcer    513
# 721                       Spondylosis And Allied Disorders    513
# 255.4                         Corticoadrenal Insufficiency    511
# 332                                    Parkinson'S Disease    510
# 536.3                                        Gastroparesis    509
# 710                  Diffuse Diseases Of Connective Tissue    507
# 332.0                                    Paralysis Agitans    506
# 253.6                   Other Disorders Of Neurohypophysis    505
# 455                                            Hemorrhoids    504
# 459.81      Venous (Peripheral) Insufficiency, Unspecified    503
# 398.9       Other And Unspecified Rheumatic Heart Diseases    499
# 398                          Other Rheumatic Heart Disease    499
# 787.20                              Dysphagia, Unspecified    499
# 202      Other Malignant Neoplasms Of Lymphoid And Hist...    498
# 557.0            Acute Vascular Insufficiency Of Intestine    496
# 320-326  Inflammatory Diseases Of The Central Nervous S...    494
# 428.21                                               Acute    492
# 719               Other And Unspecified Disorders Of Joint    491
# 441.2         Thoracic Aneurysm Without Mention Of Rupture    490
# 211      Benign Neoplasm Of Other Parts Of Digestive Sy...    489
# 920-924                Contusion With Intact Skin Surface     489
# 784.3                                              Aphasia    488
# 724.2                                              Lumbago    487
# 765.26                            31-32 Weeks Of Gestation    487
# 438.2                               Hemiplegia/Hemiparesis    483
# 873.4                Face, Without Mention Of Complication    480
# 444                       Arterial Embolism And Thrombosis    479
# 861                               Injury To Heart And Lung    476
# 511.8    Other Specified Forms Of Effusion, Except Tube...    475
# 530.1                                          Esophagitis    475
# 414.02               Of Autologous Biological Bypass Graft    474
# 041.3                               Friedländer'S Bacillus    473
# 996.72     Due To Other Cardiac Device, Implant, And Graft    473
# 766      Disorders Relating To Long Gestation And High ...    472
# 808                                     Fracture Of Pelvis    472
# 432          Other And Unspecified Intracranial Hemorrhage    471
# 303.0                         Acute Alcoholic Intoxication    469
# 786.3                                           Hemoptysis    468
# 070.3    Viral Hepatitis B Without Mention Of Hepatic Coma    468
# 038.42                          Escherichia Coli [E. Coli]    467
# 852.0    Subarachnoid Hemorrhage Following Injury Witho...    465
# 438.89       Other Late Effects Of Cerebrovascular Disease    465
# 198.8                                Other Specified Sites    465
# 356        Hereditary And Idiopathic Peripheral Neuropathy    465
# 779.89   Other Specified Conditions Originating In The ...    458

# %%
selected_groups = open('selected_icd_groups.txt').readlines()
selected_groups = [i.split()[0] for i in selected_groups]
selected_groups = [group_string_to_tuple(i) for i in selected_groups]
selected_groups[:5]
# Out:
# [((401,), (405,)), ((460,), (519,)), ((401,),), ((280,), (289,)), ((427,),)]

# %%
# %%time

selected_group_diagnosis = {
    i: {group_tuple_to_string(j) for j in group_diagnosis[i] if j in selected_groups}
    for i in group_diagnosis
}

data = [
    [i[0], i[1], j]
    for i in selected_group_diagnosis
    for j in selected_group_diagnosis[i]
]
# Out:
# CPU times: user 7.02 s, sys: 36 ms, total: 7.05 s
# Wall time: 7.05 s

# %%
df = pandas.DataFrame(data, columns=['subject_id', 'hadm_id', 'code'])
df.set_index(['subject_id', 'hadm_id', 'code'], inplace=True)
df.sort_index(inplace=True)
df.at[:, 'present'] = True
df = df.unstack(fill_value=False)['present'].astype('bool')
df
# Out:
# code                  038    070  150-159  160-165    162  190-199  200-208  \
# subject_id hadm_id
# 3          145834    True  False    False    False  False    False    False
# 4          185777   False  False    False    False  False    False    False
# 6          107064   False  False    False    False  False    False    False
# 9          150750   False  False    False    False  False    False    False
# 11         194540   False  False    False    False  False     True    False
# ...                   ...    ...      ...      ...    ...      ...      ...
# 99985      176670    True  False    False    False  False    False    False
# 99991      151118    True  False    False    False  False    False    False
# 99992      197084   False  False    False    False  False    False    False
# 99995      137810   False  False    False    False  False    False    False
# 99999      113369   False  False    False    False  False    False    False
#
# code                  244    250  250.4  ...    769  780.3  785.51  785.52  \
# subject_id hadm_id                       ...
# 3          145834   False  False  False  ...  False  False   False   False
# 4          185777   False  False  False  ...  False  False   False   False
# 6          107064   False  False  False  ...  False  False   False   False
# 9          150750   False  False  False  ...  False  False   False   False
# 11         194540   False  False  False  ...  False  False   False   False
# ...                   ...    ...    ...  ...    ...    ...     ...     ...
# 99985      176670    True  False  False  ...  False  False   False    True
# 99991      151118   False   True  False  ...  False  False   False   False
# 99992      197084   False  False  False  ...  False  False   False   False
# 99995      137810   False   True  False  ...  False  False   False   False
# 99999      113369   False   True  False  ...  False  False   False   False
#
# code                789.5  799.0  799.02  995.9  995.91  995.92
# subject_id hadm_id
# 3          145834   False  False   False  False   False   False
# 4          185777   False  False   False  False   False   False
# 6          107064   False  False   False  False   False   False
# 9          150750   False  False   False  False   False   False
# 11         194540   False  False   False  False   False   False
# ...                   ...    ...     ...    ...     ...     ...
# 99985      176670   False  False   False   True   False    True
# 99991      151118    True  False   False   True   False    True
# 99992      197084   False  False   False  False   False   False
# 99995      137810   False  False   False  False   False   False
# 99999      113369   False  False   False  False   False   False
#
# [51422 rows x 89 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
