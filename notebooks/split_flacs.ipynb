# %%
import os
import numpy
import wfdb
import flacdb
import shutil
import split_flac
import bloodpressure

# %%
root = '/home/kuprel/mimic3wdb/filtered/36/'
dirs = os.listdir(root)
paths = []
for i in dirs:
    files = [i for i in os.listdir(root + i) if '.flac' in i and 'x' not in i and 'y' not in i]
    paths += sorted({root + i + '/' + j.split('.')[0] for j in files})

# %%
rec_orig = wfdb.rdrecord('3681988_0003', pb_dir='mimic3wdb/36/3681988')

# %%
path = '/home/kuprel/mimic3wdb/filtered/36/3651462/3651462_0034'
split_flac.split(path)
rec_bp = bloodpressure.read_record(path)

# %%
rec = wfdb.rdheader(path)
rec_x = wfdb.rdheader(path + '_x')
rec_y = wfdb.rdheader(path + '_y')
is_y = numpy.array([bloodpressure.sig_is_y(j) for j in rec.sig_name])

# %%
bloodpressure.read_data(rec_x, path + '_x')
# Out:
# (array([[-22,   4,   1],
#         [-20,   3,   1],
#         [-21,   6,   1],
#         ...,
#         [-29,   9, -14],
#         [-28,   8, -13],
#         [-28,   9, -12]], dtype=int16), 125)

# %%
path = '/home/kuprel/mimic3wdb/filtered/35/3526255/3526255_0012'
split_flac.split(path)
rec_bp = bloodpressure.read_record(path)

# %%
failed = [i.strip() for i in open('failed.txt').readlines()]

# %%
split_flac.split('/home/kuprel/mimic3wdb/filtered/35/3509294/3509294_0011')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-7f2cee4f791c> in <module>
# ----> 1 split_flac.split('/home/kuprel/mimic3wdb/filtered/35/3509294/3509294_0011')
#
# ~/blood-pressure/split_flac.py in split(path)
#      20
#      21 def split(path):
# ---> 22     rec = flacdb.read_record(path)
#      23     is_y = numpy.array([bloodpressure.sig_is_y(j) for j in rec.sig_name])
#      24
#
# ~/blood-pressure/flacdb.py in read_record(path, x_only, y_only)
#      45         data, rate = soundfile.read(path + '.flac', dtype='int16', always_2d=True)
#      46     else:
# ---> 47         data = _read_blocks(hdr, path)
#      48
#      49     hdr.p_signal = to_physical(data, hdr)
#
# ~/blood-pressure/flacdb.py in _read_blocks(hdr, path)
#      31         blocks = sf.blocks(blocksize=MAXBLOCKSIZE, dtype='int16', always_2d=True)
#      32
# ---> 33         for i, block in enumerate(blocks):
#      34             data[i*MAXBLOCKSIZE:(i+1)*MAXBLOCKSIZE] = block
#      35
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in blocks(self, blocksize, overlap, frames, dtype, always_2d, fill_value, out)
#    1096
#    1097             toread = min(blocksize - output_offset, frames)
# -> 1098             self.read(toread, dtype, always_2d, fill_value, out[output_offset:])
#    1099
#    1100             if overlap:
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in read(self, frames, dtype, always_2d, fill_value, out)
#     863             if frames < 0 or frames > len(out):
#     864                 frames = len(out)
# --> 865         frames = self._array_io('read', out, frames)
#     866         if len(out) > frames:
#     867             if fill_value is None:
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in _array_io(self, action, array, frames)
#    1308         assert array.dtype.itemsize == _ffi.sizeof(ctype)
#    1309         cdata = _ffi.cast(ctype + '*', array.__array_interface__['data'][0])
# -> 1310         return self._cdata_io(action, cdata, ctype, frames)
#    1311
#    1312     def _cdata_io(self, action, data, ctype, frames):
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in _cdata_io(self, action, data, ctype, frames)
#    1318         func = getattr(_snd, 'sf_' + action + 'f_' + ctype)
#    1319         frames = func(self._file, data, frames)
# -> 1320         _error_check(self._errorcode)
#    1321         if self.seekable():
#    1322             self.seek(curr + frames, SEEK_SET)  # Update read & write position
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in _error_check(err, prefix)
#    1353     if err != 0:
#    1354         err_str = _snd.sf_error_number(err)
# -> 1355         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1356
#    1357
#
# RuntimeError: Error : flac decoder lost sync.

# %%
for path in failed[2:]:
    try:
        split_flac.split(path)
    except:
        print(path)
# Out:
# /home/kuprel/mimic3wdb/filtered/35/3509294/3509294_0011

# %%
rec_flacdb.__dict__
# Out:
# {'record_name': '3526255_0012',
#  'n_sig': 4,
#  'fs': 125,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 926084,
#  'base_time': datetime.time(23, 56, 43, 328000),
#  'base_date': None,
#  'comments': [],
#  'sig_name': ['II', 'V', 'ABP', 'PLETH'],
#  'p_signal': array([[ 0.2345679 ,  0.5390625 ,         nan,  0.50588235],
#         [ 0.25925926,  0.53125   ,         nan,  0.50588235],
#         [ 0.24691358,  0.5546875 ,         nan,  0.50588235],
#         ...,
#         [ 0.14814815,  0.578125  , 63.28125   ,  0.44705882],
#         [ 0.16049383,  0.5703125 , 62.5       ,  0.45098039],
#         [ 0.16049383,  0.578125  , 62.5       ,  0.45490196]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['3526255_0012.dat',
#   '3526255_0012.dat',
#   '3526255_0012.dat',
#   '3526255_0012.dat'],
#  'fmt': ['80', '80', '80', '80'],
#  'samps_per_frame': [1, 1, 1, 1],
#  'skew': [None, None, None, None],
#  'byte_offset': [None, None, None, None],
#  'adc_gain': [81.0, 128.0, 1.28, 255.0],
#  'baseline': [-41, -65, -109, -128],
#  'units': ['mV', 'mV', 'mmHg', 'NU'],
#  'adc_res': [8, 8, 8, 8],
#  'adc_zero': [0, 0, 0, 0],
#  'init_value': [-22, 4, -128, 1],
#  'checksum': [14662, 4690, -136, -3607],
#  'block_size': [0, 0, 0, 0]}

# %%
root = '/home/kuprel/mimic3wdb/filtered/35/'
dirs = os.listdir(root)
paths = []
for i in dirs:
    files = [
        i for i in os.listdir(root + i)
        if '.flac' in i and 'x' not in i and 'y' not in i
    ]
    paths += sorted({root + i + '/' + j.split('.')[0] for j in files})

# %%
paths.index(path)
# Out:
# 0
