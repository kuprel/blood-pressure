# %%
import tensorflow as tf
import numpy
import os
import json, pickle
import pandas
from functools import partial, reduce
import importlib

import sys
sys.path.append('../libs')

import flacdb
import prepare_data
import initialize
import data_pipeline
import conv_model
import plot_batch

# %%
# %%time

H = initialize.load_hypes()
part = 'train'
tensors, metadata, priors = initialize.run(H, parts=[part])
dataset = data_pipeline.build(H, tensors[part], part)
model = conv_model.build(H, priors)
# Out:
# CPU times: user 3min 55s, sys: 9.43 s, total: 4min 5s
# Wall time: 4min 5s

# %%
x, y = next(iter(dataset))

# %%
model.predict_on_batch({**x, 'mask': tf.cast(x['mask'], 'float32')})
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-4-8c90cde1eb8d> in <module>
# ----> 1 model.predict_on_batch({**x, 'mask': tf.cast(x['mask'], 'float32')})
#
# ~/blood-pressure/env3p7/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in predict_on_batch(self, x)
#    1238     self._check_call_args('predict_on_batch')
#    1239     if self._experimental_run_tf_function:
# -> 1240       return training_v2_utils.predict_on_batch(self, x, standalone=True)
#    1241
#    1242     if (self._distribution_strategy and
#
# ~/blood-pressure/env3p7/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in predict_on_batch(model, x, standalone)
#     554
#     555   with backend.eager_learning_phase_scope(0):
# --> 556     return predict_on_batch_fn(inputs)  # pylint: disable=not-callable
#
# ...

# %%
# %matplotlib widget
plotter = plot_batch.init(H, x, y)
plotter()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-4fb5b9a061da> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'widget')
# ----> 2 plotter = plot_batch.init(H, x, y)
#       3 plotter()
#
# ~/blood-pressure/libs/plot_batch.py in init(H, X, Y)
#      16
#      17 def init(H, X, Y):
# ---> 18     x, y = X['signals'].numpy(), Y['pressure'].numpy()
#      19     fig, axes, lines = plot_example(H, x, y, 0)
#      20     slider = IntSlider(min=0, max=(2 ** H['batch_size_log2'])-1, value=0)
#
# KeyError: 'pressure'

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# signals (InputLayer)            [(None, 2048, 11)]   0
# __________________________________________________________________________________________________
# mask (InputLayer)               [(None, 11)]         0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_2 (Tenso [(None, 2048, 11, 1) 0           signals[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, 1, 11)]      0           mask[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 2048, 11, 128 2176        tf_op_layer_ExpandDims_2[0][0]
# ...
