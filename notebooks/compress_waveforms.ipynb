# %%
import wfdb
import flacdb
import os

# %%
# path = '/home/kuprel/mimic3wdb/filtered/30/3092544/3092544_0055'
rec = wfdb.rdrecord(path)
flacdb.write_record(rec, path)
assert(rec == flacdb.read_record(path))
os.remove(path + '.flac')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-4a587256c4ec> in <module>
#       2 rec = wfdb.rdrecord(path)
#       3 flacdb.write_record(rec, path)
# ----> 4 assert(rec == flacdb.read_record(path))
#       5 os.remove(path + '.flac')
#
# ~/blood-pressure/flacdb.py in read_record(path)
#      42         data, rate = soundfile.read(path + '.flac', dtype='int16', always_2d=True)
#      43     else:
# ---> 44         data = _read_blocks(hdr, path)
#      45
#      46     hdr.p_signal = to_physical(data, hdr)
#
# ~/blood-pressure/flacdb.py in _read_blocks(hdr, path)
#      31         blocks = sf.blocks(blocksize=max_block_size, dtype='int16', always_2d=True)
#      32
# ---> 33         for i, block in enumerate(blocks):
#      34             data[i*max_block_size:(i+1)*max_block_size] = block
#      35
#
# ...

# %%
n_frames = 2396745
data, rate = soundfile.read(
    path + '.flac', 
    frames=n_frames, 
    dtype='int16'
)
data = flacdb.to_physical(data, rec)
numpy.allclose(data, rec.p_signal[:n_frames], equal_nan=True)
# Out:
# True

# %%
rec.__dict__
# Out:
# {'record_name': '3488291_0017',
#  'n_sig': 6,
#  'fs': 125,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 16349375,
#  'base_time': datetime.time(22, 56, 35, 848000),
#  'base_date': None,
#  'comments': ['Final alignment uncertain'],
#  'sig_name': ['RESP', 'PLETH', 'ABP', 'II', 'V', 'AVR'],
#  'p_signal': array([[8.85766646e-02, 2.18084066e+00, 1.85021467e+02, 6.40136719e-01,
#          9.44824219e-01, 4.50146628e-01],
#         [9.52962737e-02, 2.17302053e+00, 1.85021467e+02, 6.29882812e-01,
#          9.55078125e-01, 4.75073314e-01],
#         [1.02626756e-01, 2.16520039e+00, 1.85021467e+02, 6.60156250e-01,
#          9.59960938e-01, 5.00000000e-01],
#         ...,
#         [8.26511912e-01, 1.58455523e+00, 1.60110974e+02, 1.49902344e-01,
#          7.50000000e-01, 6.80351906e-01],
#         [8.13683568e-01, 1.56109482e+00, 1.57668769e+02, 1.49902344e-01,
#          7.50000000e-01, 6.74975562e-01],
# ...

# %%
rec.__dict__
# Out:
# {'record_name': '3092544_0055',
#  'n_sig': 3,
#  'fs': 125,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 5443328,
#  'base_time': datetime.time(21, 46, 27, 16000),
#  'base_date': None,
#  'comments': [],
#  'sig_name': ['II', 'ABP', 'ICP'],
#  'p_signal': array([[-2.22222222e-01,  1.04687500e+02,  7.91878173e+00],
#         [-1.85185185e-01,  1.03645833e+02,  7.71573604e+00],
#         [-1.72839506e-01,  1.02604167e+02,  7.51269036e+00],
#         ...,
#         [-9.87654321e-02,  8.90625000e+01,  1.90862944e+01],
#         [-9.87654321e-02,  9.53125000e+01,  1.86802030e+01],
#         [-8.64197531e-02,  1.04687500e+02,  1.79695431e+01]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['3092544_0055.dat', '3092544_0055.dat', '3092544_0055.dat'],
#  'fmt': ['80', '80', '80'],
#  'samps_per_frame': [1, 1, 1],
#  'skew': [None, None, None],
#  'byte_offset': [None, None, None],
#  'adc_gain': [81.0, 1.92, 9.85],
# ...
